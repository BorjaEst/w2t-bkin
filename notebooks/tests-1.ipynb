# %%
from w2t_bkin.ingest import pose
from pathlib import Path

# %%
path = Path("/mnt/c/data/W2T_202509_BA/data/interim/MLA-026805/20250905/sleap-pose/example_fileSLEAP.h5")
data, metadata = pose.import_sleap_pose(h5_path=path)

# %%
import numpy as np

fps = 150
reference_times = np.arange(len(data)) / fps
estimation = pose.build_pose_estimation((data, metadata), reference_times)
estimation
# Out:
# PoseEstimation_subject_0bfb1c5c ndx_pose.pose.PoseEstimation at 0x123407167474368
# Fields:
#   description: Pose estimation using SLEAP. Scorer: unknown. Skeleton: subject_0bfb1c5c
#   pose_estimation_series: {
#     earbaseL <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     eartipL <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     frontpawL <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     frontpawR <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     lowerlip <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     noseback <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     nosetip <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     pupilL <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     shoulder <class 'ndx_pose.pose.PoseEstimationSeries'>,
#     tm_joint <class 'ndx_pose.pose.PoseEstimationSeries'>
#   }
#   scorer: unknown
#   skeleton: subject_0bfb1c5c abc.Skeleton at 0x123405030730208
# Fields:
#   edges: []
# ...

# %%
from pathlib import Path
from rich import print

# %% [markdown]
# ### Load configuration

# %%
from w2t_bkin import config, sync, behavior, session
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from w2t_bkin import config, sync, behavior, session
#
# File ~/w2t-bkin/src/w2t_bkin/__init__.py:70
#       1 """W2T Body Kinematics Pipeline (w2t_bkin).
#       2
#       3 A modular, reproducible Python pipeline for processing multi-camera rodent
#    (...)
#      66 See docs/ for detailed module documentation and design principles.
#      67 """
#      69 # Import main modules for convenient access
# ---> 70 from . import behavior, bpod, config, facemap, pipeline, pose, session, sync, transcode, utils
#      72 __all__ = [
#      73     "behavior",
#      74     "bpod",
#    (...)
#      82     "utils",
#      83 ]
#
# File ~/w2t-bkin/src/w2t_bkin/config.py:98
#      94     import tomli as tomllib
#      96 from pydantic import ValidationError, field_validator, model_validator
# ---> 98 from .config import Config
#      99 from .utils import compute_hash, read_toml
#     101 # Enum constants for validation
#
# ImportError: cannot import name 'Config' from partially initialized module 'w2t_bkin.config' (most likely due to a circular import) (/home/borja/w2t-bkin/src/w2t_bkin/config.py)

# %% [markdown]
# ### Ingest and verify

# %%
session_file = Path("data/raw/Session-000001/session.toml")
nwbfile = session.create_nwb_file()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 session_file = Path("data/raw/Session-000001/session.toml")
#       2 nwbfile = session.create_nwb_file()
#
# NameError: name 'Path' is not defined

# %% [markdown]
# ### Parse Bpod behavioral data

# %%
from w2t_bkin.events import parse_bpod

bpod_data = parse_bpod(
    session_dir=Path(session.session_dir),  # ..../tests/fixtures/data/raw/Session-000001
    pattern=session.bpod.path,  # 'Bpod/*.mat'
    order="name_asc",
    continuous_time=False,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from w2t_bkin.events import parse_bpod
#       3 bpod_data = parse_bpod(
#       4     session_dir=Path(session.session_dir),  # ..../tests/fixtures/data/raw/Session-000001
#       5     pattern=session.bpod.path,  # 'Bpod/*.mat'
#       6     order="name_asc",
#       7     continuous_time=False,
#       8 )
#
# ModuleNotFoundError: No module named 'w2t_bkin.events'

# %%
behavior.extract_task(bpod_data)

# %%
behavior.extract_task_recording(bpod_data)

# %%
behavior.extract_trials_table(bpod_data)

# %% [markdown]
# ### Import pose data

# %% [markdown]
# ### Import facemap data

# %% [markdown]
# ### Transcode videos for better storage

# %% [markdown]
# ### Synchronize to reference timebase

# %%
ttl_patterns = {ttl.id: ttl.paths for ttl in session.TTLs}
ttl_pulses = sync.get_ttl_pulses(ttl_patterns, session.session_dir)
trial_offsets, warnings = sync.align_bpod_trials_to_ttl(
    trial_type_configs=session.bpod.trial_types,
    bpod_data=bpod_data,
    ttl_pulses=ttl_pulses,
)

# %%
behavior.extract_task(bpod_data)

# %%
behavior.extract_task_recording(bpod_data, trial_offsets)

# %%
behavior.extract_trials_table(bpod_data, trial_offsets)

# %% [markdown]
# ### Assemble NWB

# %%
output_dir = Path("data/external/Session-000001")
provenance = {
    "config_hash": "abc123",
    "session_hash": "def456",
    "software": {"name": "w2t_bkin", "version": "0.1.0"},
    "timebase": {"source": "nominal_rate"},
}
nwb_path = nwb.assemble_nwb(manifest, cfg, provenance, output_dir)

# %% [markdown]
# ### Validate and QC (Phase 5 - not yet implemented)

# %%
from pathlib import Path

# %%
from pynwb import NWBHDF5IO, NWBFile
from rich import print

# %% [markdown]
# ### Call the pipeline for processing a session

# %%
! python -m w2t_bkin.cli run --help
# Out:
#
#  Usage: python -m w2t_bkin.cli run [OPTIONS] CONFIG_PATH SUBJECT_ID SESSION_ID
#
#  Run the pipeline for a single session.
#
#  This command executes all 6 phases of the pipeline: 0. Initialization - Load
#  config and create NWBFile 1. Discovery - Find and verify files 2. Ingestion -
#  Process Bpod and TTL data 3. Synchronization - Compute alignment statistics 4.
#  Assembly - Build NWB behavior tables 5. Finalization - Write, validate, and
#  create sidecars
#  Example:     $ python -m w2t_bkin.cli run config.toml subject-001 session-001
#  $ python -m w2t_bkin.cli run config.toml subject-001 session-001
#  --skip-validation
#
# ╭─ Arguments ──────────────────────────────────────────────────────────────────╮
# │ *    config_path      PATH  Path to config.toml file [required]              │
# │ *    subject_id       TEXT  Subject identifier (e.g., 'subject-001')         │
# │                             [required]                                       │
# │ *    session_id       TEXT  Session identifier (e.g., 'session-001')         │
# │                             [required]                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭─ Options ────────────────────────────────────────────────────────────────────╮
# │ --skip-bpod                  Skip Bpod processing                            │
# │ --skip-pose                  Skip pose estimation                            │
# │ --skip-ttl                   Skip TTL processing                             │
# │ --skip-verification          Skip frame/TTL verification                     │
# │ --skip-validation            Skip NWB validation                             │
# │ --force                      Overwrite existing outputs                      │
# │ --help                       Show this message and exit.                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
! python -m w2t_bkin.cli run 'configs/standard.toml' 'subject-002' 'session_20251120' \
    --skip-pose \
    --force
# Out:
# ╭───────────────────────────────╮
# │ W2T Body Kinematics Pipeline  │
# │ Subject: subject-002          │
# │ Session: session_20251120     │
# │ Config: configs/standard.toml │
# ╰───────────────────────────────╯
# [17:31:01] INFO     Loading configuration and creating           ]8;id=899089;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=369048;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#245\245]8;;\
#                     NWBFile...
#            INFO       Project: w2t-bkin-pipeline                 ]8;id=336921;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=296068;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#249\249]8;;\
#            INFO       Raw root: /home/borja/w2t-bkin/data/raw    ]8;id=912610;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=243427;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#250\250]8;;\
#            INFO       Output root:                               ]8;id=986083;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=916747;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#251\251]8;;\
#                     /home/borja/w2t-bkin/data/processed
#            INFO       NWBFile: identifier='session_20251120'     ]8;id=863475;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=213967;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#261\261]8;;\
#            INFO       Subject: M002                              ]8;id=512382;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=782176;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#263\263]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Discovering files and verifying              ]8;id=644529;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=298979;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#267\267]8;;\
#                     synchronization...
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_camera': 1 file(s), 8580 pulses   ]8;id=461695;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=243407;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#308\308]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_cue': 1 file(s), 3 pulses         ]8;id=672712;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=811900;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#308\308]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_hitmiss': 1 file(s), 4 pulses     ]8;id=439566;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=70692;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#308\308]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Processing Bpod and TTL data...              ]8;id=438388;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=12189;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#342\342]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_camera': 8580 pulses,             ]8;id=674967;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=379822;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#367\367]8;;\
#                     range=[2.796, 59.991] s
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_cue': 3 pulses, range=[22.741,    ]8;id=611501;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=924539;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#367\367]8;;\
#                     43.840] s
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_hitmiss': 4 pulses,               ]8;id=705218;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=665617;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#367\367]8;;\
#                     range=[25.078, 55.208] s
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Computing alignment statistics...            ]8;id=911370;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=818421;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#382\382]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Building behavior tables...                  ]8;id=539798;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=226975;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#406\406]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Writing NWB file and creating sidecars...    ]8;id=779292;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=198124;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#446\446]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_hitmiss': 1 file(s), 4 pulses     ]8;id=439566;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=70692;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#308\308]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Processing Bpod and TTL data...              ]8;id=438388;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=12189;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#342\342]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_camera': 8580 pulses,             ]8;id=674967;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=379822;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#367\367]8;;\
#                     range=[2.796, 59.991] s
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_cue': 3 pulses, range=[22.741,    ]8;id=611501;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=924539;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#367\367]8;;\
#                     43.840] s
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       TTL 'ttl_hitmiss': 4 pulses,               ]8;id=705218;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=665617;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#367\367]8;;\
#                     range=[25.078, 55.208] s
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Computing alignment statistics...            ]8;id=911370;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=818421;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#382\382]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Building behavior tables...                  ]8;id=539798;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=226975;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#406\406]8;;\
#   Phase 0: Initialization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Writing NWB file and creating sidecars...    ]8;id=779292;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=198124;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#446\446]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       NWB file: session_20251120.nwb (0.2 MB)    ]8;id=38407;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=380379;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#463\463]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       Alignment stats: alignment_stats.json      ]8;id=631443;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=782777;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#469\469]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       Provenance: provenance.json                ]8;id=179066;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=428165;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#473\473]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Validating NWB file with nwbinspector...     ]8;id=763797;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=192496;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#478\478]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       NWB file: session_20251120.nwb (0.2 MB)    ]8;id=38407;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=380379;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#463\463]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       Alignment stats: alignment_stats.json      ]8;id=631443;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=782777;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#469\469]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO       Provenance: provenance.json                ]8;id=179066;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=428165;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#473\473]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#            INFO     Validating NWB file with nwbinspector...     ]8;id=763797;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=192496;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#478\478]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [17:31:02] INFO       Validation passed (0 warnings)             ]8;id=996185;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=377626;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#490\490]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 5: Finalization & Validation ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#
# ✓ Pipeline completed successfully
#
# ✓ Success! NWB file:
# /home/borja/w2t-bkin/data/processed/subject-002/session_20251120/session_2025112
# 0.nwb
# ✓ Validation passed (0 warnings)
# [17:31:02] INFO       Validation passed (0 warnings)             ]8;id=996185;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py\pipeline.py]8;;\:]8;id=377626;file:///home/borja/w2t-bkin/src/w2t_bkin/pipeline.py#490\490]8;;\
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 0: Initialization            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 1: Discovery & Verification  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 2: Ingestion                 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 3: Synchronization           ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 4: Assembly                  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#   Phase 5: Finalization & Validation ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#
# ✓ Pipeline completed successfully
#
# ✓ Success! NWB file:
# /home/borja/w2t-bkin/data/processed/subject-002/session_20251120/session_2025112
# 0.nwb
# ✓ Validation passed (0 warnings)

# %% [markdown]
# ### Validate and QC

# %%
! nwbinspector 'data/processed/subject-002/session_20251120/session_20251120.nwb'
# Out:
#
#
# **************************************************
# NWBInspector Report Summary
#
# Timestamp: 2025-12-01 17:31:03.425519+01:00
# Platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.35
# NWBInspector version: 0.6.5
#
# Found 3 issues over 1 files:
#        3 - PYNWB_VALIDATION
# **************************************************
#
#
# 0  PYNWB_VALIDATION
# ===================
#
# 0.0  data/processed/subject-002/session_20251120/session_20251120.nwb and 2 other files: root/general/was_generated_by - 'None' object at location 'general/was_generated_by'
#        Message: incorrect shape - expected '[*, 2]', got '(9,)'
#
#
#
# **************************************************
# NWBInspector Report Summary
#
# Timestamp: 2025-12-01 17:31:03.425519+01:00
# Platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.35
# NWBInspector version: 0.6.5
#
# Found 3 issues over 1 files:
#        3 - PYNWB_VALIDATION
# **************************************************
#
#
# 0  PYNWB_VALIDATION
# ===================
#
# 0.0  data/processed/subject-002/session_20251120/session_20251120.nwb and 2 other files: root/general/was_generated_by - 'None' object at location 'general/was_generated_by'
#        Message: incorrect shape - expected '[*, 2]', got '(9,)'

# %% [markdown]
# ### Load NWB file and inspect contents

# %%
nwbpath = Path("data/processed/subject-002/session_20251120/session_20251120.nwb")
io = NWBHDF5IO(nwbpath, mode="r")
nwbfile = io.read()
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x137589151693936
# Fields:
#   data_collection: Data collected using Bpod behavioral control system.
# Video recorded at 30 fps using synchronized cameras.
# Pose estimated using DeepLabCut model trained on lab-specific data.
#
#   devices: {
#     bpod <class 'pynwb.device.Device'>,
#     camera_0 <class 'pynwb.device.Device'>,
#     camera_1 <class 'pynwb.device.Device'>
#   }
#   experiment_description: Water-to-target behavioral task with simultaneous video tracking.
# Animal navigates to target location while pose is tracked using
# DeepLabCut and synchronized with Bpod behavioral events.
#
#   experimenter: ['Esteban, Borja' 'Python, Code']
#   file_create_date: [datetime.datetime(2025, 12, 1, 17, 31, 1, 465722, tzinfo=tzoffset(None, 3600))]
#   identifier: session_20251120
#   institution: Neural Dynamics Laboratory, University Example
#   keywords: <StrDataset for HDF5 dataset "keywords": shape (5,), type "|O">
#   lab: Larkum Lab
#   notes: Session conducted with standard lighting conditions.
# Animal showed normal behavior throughout the session.
# All equipment functioning properly.
#
#   pharmacology: None
#   protocol: IACUC-2025-001
#   related_publications: []
#   session_description: Behavioral training session with pose tracking and camera synchronization
#   session_id: 000001
#   session_start_time: 2025-11-20 14:30:00+00:00
#   slices: N/A - in vivo experiment
#   source_script: /home/borja/w2t-bkin/src/w2t_bkin/cli.py
#   source_script_file_name: cli.py
#   stimulus_notes: Visual target displayed on LED screen at variable locations
#   subject: subject pynwb.file.Subject at 0x137589152153904
# Fields:
#   age: P84D
#   age__reference: birth
#   date_of_birth: 2024-10-23 00:00:00+00:00
#   description: Adult male C57BL/6J mouse, 12 weeks old
#   genotype: C57BL/6J wild-type
#   sex: M
#   species: Mus musculus
#   strain: C57BL/6J
#   subject_id: M002
#   weight: 0.025 kg
#
#   surgery: Cranial window implant surgery performed 2 weeks prior to recording.
# No complications observed. Animal recovered fully.
#
#   timestamps_reference_time: 2025-11-20 14:30:00+00:00
#   virus: None
#   was_generated_by: <StrDataset for HDF5 dataset "was_generated_by": shape (9,), type "|O">

# %%
from pathlib import Path

# %%
from pynwb import NWBHDF5IO, NWBFile
from rich import print

# %% [markdown]
# ### Call the pipeline for processing a session

# %% [markdown]
# ### Validate and QC

# %%
! nwbinspector 'data/w2t-bkin-jolte/data/processed/SNA-144233/day1/day1.nwb'
# Out:
#
#
# **************************************************
# NWBInspector Report Summary
#
# Timestamp: 2026-01-12 19:02:36.351007+01:00
# Platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.35
# NWBInspector version: 0.6.5
#
# Found 4 issues over 1 files:
#        3 - PYNWB_VALIDATION
#        1 - BEST_PRACTICE_SUGGESTION
# **************************************************
#
#
# 0  PYNWB_VALIDATION
# ...
#
# 0.0  data/w2t-bkin-jolte/data/processed/SNA-144233/day1/day1.nwb and 2 other files: root/general/was_generated_by - 'None' object at location 'general/was_generated_by'
#        Message: incorrect shape - expected '[*, 2]', got '(9,)'
#
# 1  BEST_PRACTICE_SUGGESTION
# ...
#
# 1.1  data/w2t-bkin-jolte/data/processed/SNA-144233/day1/day1.nwb: check_single_row - 'TaskArgumentsTable' object with name 'task_arguments'
#        Message: This table has only a single row; it may be better represented by another data type.

# %% [markdown]
# ### Load NWB file and inspect contents

# %%
nwbpath = Path("/home/borja/w2t-bkin/data/project-1-jelte/data/processed/SNA-144233/day1/day1.nwb")
io = NWBHDF5IO(nwbpath, mode="r")
nwbfile = io.read()
nwbfile
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 nwbpath = Path("data/w2t-bkin-jolte/data/processed/SNA-144233/day1/day1.nwb")
# ----> 2 io = NWBHDF5IO(nwbpath, mode="r")
#       3 nwbfile = io.read()
#       4 nwbfile
#
# File ~/w2t-bkin/.venv/lib/python3.10/site-packages/hdmf/utils.py:592, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     590 def func_call(*args, **kwargs):
#     591     pargs = _check_args(args, kwargs)
# --> 592     return func(args[0], **pargs)
#
# File ~/w2t-bkin/.venv/lib/python3.10/site-packages/pynwb/__init__.py:437, in NWBHDF5IO.__init__(self, **kwargs)
#     435 if load_namespaces:
#     436     tm = get_type_map()
# --> 437     super().load_namespaces(tm, path, file=file_obj, driver=driver, aws_region=aws_region)
#     438     manager = BuildManager(tm)
# ...

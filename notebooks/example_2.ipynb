# %%
from pathlib import Path

# %%
from pynwb import NWBHDF5IO, NWBFile
from rich import print

# %% [markdown]
# ### Call the pipeline for processing a session

# %%
! python -m w2t_bkin.cli run 'configs/standard.toml' 'subject-002' 'session_20251120'

# %% [markdown]
# ### Validate and QC

# %%
! nwbinspector 'data/processed/subject-002/session_20251120/session_file.nwb'

# %% [markdown]
# ### Load NWB file and inspect contents

# %%
nwbpath = Path("data/processed/subject-002/session_20251120/session_file.nwb")
with NWBHDF5IO(nwbpath, mode="r") as io:
    read_nwbfile = io.read()
